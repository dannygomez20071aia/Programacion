# %% [markdown]
# <a href="https://colab.research.google.com/github/dannygomez20071aia/Programacion/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio de hola mundo N1
# ## Python Lenguajes
# ### Tipos de lenguaje
# ### C++
# ### PASCAL
# ### RUBY
# ### PYTHON

# %% [markdown]
# # USO DE LENGUAJE C++
# ## Ingreso de HOLA MUNDO
# ### C++ es un lenguaje de programación de propósito general, muy potente y eficiente, que se utiliza para desarrollar programas donde se requiere alto rendimiento y control del sistema.

# %%
using namespace std;

int main() {
    cout << "Hola Mundo";
    return 0;
}

# %% [markdown]
# # USO DE LENGUAJE PASCAL
# ## Ingreso de HOLA MUNDO
# ### Pascal es un lenguaje de programación creado principalmente para enseñar programación, destacándose por su claridad, orden y facilidad de lectura.

# %%
program HolaMundo;

begin
  writeln('Hola Mundo');
end.

# %% [markdown]
# # USO DE LENGUAJE RUBY
# ## Ingreso de HOLA MUNDO
# ### Ruby es un lenguaje de programación interpretado, orientado a objetos y de alto nivel, diseñado para ser simple, claro y fácil de leer.

# %%
puts "HOLA MUNDO "

# %% [markdown]
# # USO DE LENGUAJE PYTHON
# ## Ingreso de HOLA MUNDO
# ### Python es un lenguaje de programación de alto nivel, interpretado y muy fácil de aprender, creado para escribir código de forma clara y sencilla.

# %%
print("HOLA MUNDO")
